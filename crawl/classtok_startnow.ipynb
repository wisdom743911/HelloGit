# %%
import requests
from bs4 import BeautifulSoup
import time
import datetime
import pandas as pd

start  = time.time()

# %%
url = 'https://www.classtok.net/modoo/start_now'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
elements = soup.select('body > div.main_wrap > div > div > ul > div > li > div > a.product_info')

# %%
links = []

for i in range(len(elements)):
    links.append('https://classtok.net' + str(elements[i]).replace('<a class="product_info" href="', '').split('">\n<span>')[0])

classtok_df = pd.DataFrame(columns=['site', 'link', 'title', 'teacher', 'category_1', 'category_2', 's_price', 'discount', 'contentment'])

onetime = []

for element in elements:
    
    site = '클래스톡'
    try:
        likes = element.select_one('.product_star').text.split()[0]
    except:
        likes = ''
    
    onetime.append({
        "site" : site,
        "title" : element.select_one('h2').text,
        "category_2" : element.select_one('span').text.split(' · ')[0],
        "teacher" : element.select_one('span').text.split(' · ')[1],
        "s_price" : element.select_one('.price_info').text.split('\n')[1],
        "discount" : element.select_one('.price_info').text.split('\n')[2].replace(' 할인',''),
        "contentment" : likes,
        "link" : 'https://www.classtok.net' + element.get('href'),
    })
classtok_df = classtok_df.append(onetime)

# %%
classtok_df
# Out:
#      site                                             link  \
# 0    클래스톡  https://www.classtok.net/class/classDetail/2223
# 1    클래스톡  https://www.classtok.net/class/classDetail/2652
# 2    클래스톡  https://www.classtok.net/class/classDetail/2593
# 3    클래스톡  https://www.classtok.net/class/classDetail/1439
# 4    클래스톡  https://www.classtok.net/class/classDetail/2499
# ..    ...                                              ...
# 342  클래스톡   https://www.classtok.net/class/classDetail/665
# 343  클래스톡  https://www.classtok.net/class/classDetail/2996
# 344  클래스톡  https://www.classtok.net/class/classDetail/2838
# 345  클래스톡  https://www.classtok.net/class/classDetail/1260
# 346  클래스톡  https://www.classtok.net/class/classDetail/2381
#
#                            title  teacher category_1 category_2   s_price  \
# 0                 쉽게 배우는 힐링 타로교실  LaForce        NaN             월40,000원
# 1    '창업가'에게 꼭 필요한 투자받는 IR 피칭 비법      최현정        NaN        스피치  월39,900원
# 2     '오늘도 수고했어' 당신을 위한 힐링 캘리그라피      석재원        NaN        글쓰기  월25,000원
# 3         나를 위한 힐링, 칼림바 연주 어떠세요?       가희        NaN         음악  월35,000원
# 4     연예인 운동법 X-Combine 다이어트 홈트!    Ferry        NaN         운동   월9,900원
# ..                           ...      ...        ...        ...       ...
# 342           누구나 가능한 홈요가 기초 클래스     서연코치        NaN         요가  월19,000원
# 343            내 몸을 망치지 않는 홈트레이닝       청쌤        NaN         운동  월30,000원
# 344            마케팅 PPT 활용 콘텐츠 제작      neo        NaN        마케팅  월33,000원
# 345  집에서 칵테일을 마신다고? 나만의 홈bar 만들기     Bar규        NaN         음료  월25,000원
# 346            인싸 신입사원 되는 말하기 기술      서민정        NaN        스피치  월19,900원
#
#     discount contentment
# 0        49%
# 1        49%
# 2        68%           5
# 3        61%         4.5
# 4        87%
# ..       ...         ...
# 342      73%         4.9
# 343      62%           5
# 344      51%
# 345    63.7%           5
# 346      75%
#
# [347 rows x 9 columns]

# %%
print('time: ', round((time.time() - start)/60, 1), '분', sep='')
print('\n')
# Out:
# time: 0.8분

# %%
classtok_df.to_csv(f'./classtok_{datetime.datetime.now().strftime("%y%m%d%H%M%S")}.csv', encoding='utf-8')

# %%
print('전체')
print('time: ', round((time.time() - start)/60, 1), '분', sep='')
print('\n')
print('total: ', len(classtok_df), sep='')
# Out:
# 전체
# time: 0.8분
#
#
# total: 347
