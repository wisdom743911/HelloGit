# %% [markdown]
# ### 수정중 : 폰트 가운데 정렬, img 위치, 해상도 등 부수적인 문제만 남은 상태

# %%
# 1. 프로젝트 생성

# %%
# !mkdir -p webservice/static
# !mkdir -p webservice/templates
# !touch webservice/webservice.py
# !touch webservice/templates/index.html
#!cp datas/model.pkl webservice/models
# !tree webservice

# %%
# 2. route 코드 작성

# %%
# %%writefile webservice/webservice.py
from flask import *
from flask_sqlalchemy import SQLAlchemy
from datetime import datetime

app = Flask(__name__)
app.config.update(TEMPLATES_AUTO_RELOAD=True, DEBUG=True)

# Setting Mysql
app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False
app.config['SQLALCHEMY_DATABASE_URI'] = 'mysql://root:dss@52.78.38.124:3306/crawled'
mysql_db = SQLAlchemy(app)

class Crawling(mysql_db.Model):
    
    __tablename__ = 'search'
        
    site = mysql_db.Column(mysql_db.String(30), nullable=False)
    link = mysql_db.Column(mysql_db.String(100), primary_key=True)
    title = mysql_db.Column(mysql_db.String(200), nullable=False)
    teacher = mysql_db.Column(mysql_db.String(50), nullable=False)
    category_1 = mysql_db.Column(mysql_db.String(20), nullable=False)
    category_2 = mysql_db.Column(mysql_db.String(20), nullable=False)
    s_price = mysql_db.Column(mysql_db.String(20), nullable=False)
    discount = mysql_db.Column(mysql_db.String(20), nullable=False)
    contentment = mysql_db.Column(mysql_db.String(20), nullable=False)
    crawling_time = mysql_db.Column(mysql_db.String(20), nullable=False)

    def __init__(self, site, link, title, category_1, category_2, s_price, discount, contentment, crawling_time):
        self.site = site
        self.link = link
        self.title = title
        self.category_1 = category_1
        self.category_2 = category_2
        self.s_price = s_price
        self.discount = discount
        self.contentment = contentment
        self.crawling_time = crawling_time

        
class NewClass(mysql_db.Model):
    
    __tablename__ = 'new_class'
        
    site = mysql_db.Column(mysql_db.String(30), nullable=False)
    link = mysql_db.Column(mysql_db.String(100), primary_key=True)
    title = mysql_db.Column(mysql_db.String(200), nullable=False)
    teacher = mysql_db.Column(mysql_db.String(50), nullable=False)
    category_1 = mysql_db.Column(mysql_db.String(20), nullable=False)
    category_2 = mysql_db.Column(mysql_db.String(20), nullable=False)
    s_price = mysql_db.Column(mysql_db.String(20), nullable=False)
    discount = mysql_db.Column(mysql_db.String(20), nullable=False)
    contentment = mysql_db.Column(mysql_db.String(20), nullable=False)
    crawling_time = mysql_db.Column(mysql_db.String(20), nullable=False)

    def __init__(self, site, link, title, category_1, category_2, s_price, discount, contentment, crawling_time):
        self.site = site
        self.link = link
        self.title = title
        self.category_1 = category_1
        self.category_2 = category_2
        self.s_price = s_price
        self.discount = discount
        self.contentment = contentment
        self.crawling_time = crawling_time

mysql_db.create_all()


@app.route("/")
def index():
    return render_template("index.html")


@app.route("/search", methods=['GET', 'POST'])
def search():
    result = {} 

 # 문장 가져오기
    sentence = request.values.get('sentence') # 요청을 했을때 키값이 'sentence'인 내용을 받아오는 코드
    result['sentence'] = sentence
    
    # MYSQL에서 데이터 가져오기
    results = Crawling.query.filter(Crawling.title.like('%' + sentence + '%') | Crawling.category_1.like('%' + sentence + '%') | Crawling.category_2.like('%' + sentence + '%')).all()
    datas = []
    for data in results:
        datas.append({
            'site': data.site,
            'link': data.link,
            'title': data.title,
            'teacher': data.teacher,
            'category_1': data.category_1,
            'category_2': data.category_2,
            's_price': data.s_price,
            'discount': data.discount,
            'contentment': data.contentment,
        })

    print(datas)
    
    result['datas'] = datas
    
    
    
    # save mysql
#     search_history = Crawling(site, link, title, category_1, category_2, s_price, discount, contentment, crawling_time)
#     mysql_db.session.add(search_history)
#     mysql_db.session.commit()
    
    
    return jsonify(result)

@app.route("/new_class", methods=['GET', 'POST'])
def new_class():
    result_new = {} 


    # MYSQL에서 데이터 가져오기
    results_new = NewClass.query.all()
    datas_new = []
    for data_new in results_new:
        datas_new.append({
            'site': data_new.site,
            'link': data_new.link,
            'title': data_new.title,
            'teacher': data_new.teacher,
            'category_1': data_new.category_1,
            'category_2': data_new.category_2,
            's_price': data_new.s_price,
            'discount': data_new.discount,
            'contentment': data_new.contentment,
        })

    print(datas_new)
    
    result_new['datas_new'] = datas_new
    
    
    
    # save mysql
#     search_history = Crawling(site, link, title, category_1, category_2, s_price, discount, contentment, crawling_time)
#     mysql_db.session.add(search_history)
#     mysql_db.session.commit()
    
    
    return jsonify(result_new)
app.run()
# Out:
# Overwriting webservice/webservice.py

# %%
# 3. index.html

# %%
# %%writefile webservice/templates/index.html
# <!DOCTYPE html>
# <html>
#     <link rel="preconnect" href="https://fonts.gstatic.com">
#     <link href="https://fonts.googleapis.com/css2?family=Do+Hyeon&display=swap" rel="stylesheet">
#     <style>
#       div { font-family: 'Do Hyeon', sans-serif;}
#
#      .dropdown-container{text-align: 'center';}
#
#         p1{
#           position: absolute;
#             background-color: ;
#             margin-left: 1050px;
#             object-fit: contain;
#             text-align: center;
#             top: 8px;
#         }
#
#
#     </style>
# <head>
#
# <div class="image">
#     <p1><img id="test2" src="https://i.ibb.co/0qv9tN7/dd.png"  width=22%  border="0"></p1>
#     <p2><img src="https://i.ibb.co/JBT9V7p/flask-up.png" width=22% alt="flask-up" border="0"></p2>
#
# </div>
#     <meta charset="utf-8mb4"><title>🔔당신이 원하는 수업을 찾아드립니다🔔</title>
#     <div class="container pt-3">
#         <!-- 입력창 -->
#         <div class="row">
#             <input type="text" class="col-10 form-control sentence " placeholder='"원하는 수업을 입력하세요♥"'>
#             <button type="button" class="col-2 btn btn-dark search" >검색</button>
#         </div>
#
#         <!-- 결과창 -->
#         <div class="row">
#             <div class="col-12 alert alert-dark mt-3" role="alert">
#                🤩🥳 "내가 원하는 클래스 찾기! 원하는 어떤 수업이든 알려드려요~ "🧑‍💻
#             </div>
#         </div>
#
#     <div class="image">
#     <img src="https://i.ibb.co/zsV8kh8/JJJ.png" width="95%" align= alt="JJJ" border="0">
#
#     </div>
#
#         <br>
#         <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
#         <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/js/bootstrap.bundle.min.js"></script>
#         <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/js/bootstrap.min.js"></script>
#         <link href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/css/bootstrap.min.css" rel="stylesheet" />
#
#         <!-- 카테고리 별 분류를 보여주는 버튼 -->
#
#
#             </style>
#         <div class="container btn-group pt-2">
#             <div class="dropdown-container"><!--Container wrapped around-->
#               <button data-toggle="dropdown" class="btn-outline-dark shadow p-1 mb-5 bg-body rounded mt-1 mx-2 dropdown-toggle" type="button" aria-expanded="true"> 뷰티/헬스 <span class="caret"></span>
#                   </button>
#                       <ul role="menu" class="dropdown-menu">
#                         <li><a href="#"> 💄메이크업 💅👄/a> </li>
#                         <li><a href="#"> 퍼스널컬러</a> </li>
#                         <li><a href="#"> 패션👗👜</a> </li>
#                         <li><a href="#"> 💆‍♂️셀프케어💆‍ </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 🧘PT/GX 🏋️ </a> </li>
#                         </ul>
#
#             </div><!--Container closed-->
#
#             <div class="dropdown-container"><!--Container wrapped around-->
#               <button data-toggle="dropdown" class="btn-dark shadow p-1 mb-5 bg-body rounded mt-1 mx-2 dropdown-toggle" type="button" aria-expanded="true"> 액티비티 <span class="caret"></span>
#                   </button>
#                       <ul role="menu" class="dropdown-menu">
#                         <li><a href="#"> 👯‍♂️방송댄스👯‍♂️ </a> </li>
#                         <li><a href="#"> 🤸‍댄스🤸‍ </a> </li>
#                         <li><a href="#"> 🎭연기/무용🎭 </a> </li>
#                         <li><a href="#"> 🤺스포츠/레저 🚵</a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 이색 액티비티🚴‍ </a> </li>
#                         </ul>
#
#             </div><!--Container closed-->
#
#             <div class="dropdown-container"><!--Container wrapped around-->
#               <button data-toggle="dropdown" class="btn-outline-dark shadow p-1 mb-5 bg-body rounded mt-1 mx-2 dropdown-toggle" type="button" aria-expanded="true"> 라이프 <span class="caret"></span>
#                   </button>
#                       <ul role="menu" class="dropdown-menu">
#                         <li><a href="#"> 인문/교양 </a> </li>
#                         <li><a href="#"> 인테리어 </a> </li>
#                         <li><a href="#"> 🐈‍🦔반려동물🐹🐶🐱 </a> </li
#                         <li><a href="#"> 🤱👦부모/육아👩‍👩‍👦 </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 📝출판/글쓰기🖋️ </a> </li>
#                         <li><a href="#"> 사주/타로 </a> </li>
#                         <li class="divider"></li>
#                         <li><a href="#"> 🗨️심리상담💬 </a> </li>
#                         </ul>
#
#             </div><!--Container closed-->
#
#             <div class="dropdown-container"><!--Container wrapped around-->
#               <button data-toggle="dropdown" class="btn-dark shadow p-1 mb-5 bg-body rounded mt-1 mx-2 dropdown-toggle" type="button" aria-expanded="true"> 취미/공예 <span class="caret"></span>
#                   </button>
#                       <ul role="menu" class="dropdown-menu">
#                         <li><a href="#"> 이색취미/공예 </a> </li>
#                         <li><a href="#"> 사진 </a> </li>
#                         <li><a href="#"> 🎨취미미술🎨 </a> </li>
#                         <li><a href="#"> 🖥️디지털드로잉🖥️🎨 </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 🥗요리/베이킹🍝🥗 </a> </li>
#                         <li><a href="#"> ☕🍵커피/차/술🍶🍷 </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 🎙️보컬🎤 </a> </li>
#                         <li><a href="#"> 🎸악기🎹🎺 </a> </li>
#                         <li><a href="#"> 작곡/디제잉🎼</a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 🖌️캘리그래피✒️ </a> </li>
#                         <li><a href="#"> 플라워 </a> </li>
#                         <li><a href="#"> 조향/캔들/비누 </a> </li>
#                         <li><a href="#"> 가죽/목공/공예 </a> </li>
#                         </ul>
#
#             </div><!--Container closed-->
#
#             <div class="dropdown-container"><!--Container wrapped around-->
#               <button data-toggle="dropdown" class="btn-outline-dark shadow p-1 mb-5 bg-body rounded mt-1 mx-2 dropdown-toggle" type="button" aria-expanded="true"> 머니 <span class="caret"></span>
#                   </button>
#                       <ul role="menu" class="dropdown-menu">
#                         <li><a href="#"> 투잡 </a> </li>
#                         <li><a href="#"> 마케팅 </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 📉주식투자📈 </a> </li>
#                         <li><a href="#"> 부동산 </a> </li>
#                         <li><a href="#">💶 금융지식💵</a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 창업 </a> </li>
#                         </ul>
#
#             </div><!--Container closed-->
#
#             <div class="dropdown-container"><!--Container wrapped around-->
#               <button data-toggle="dropdown" class="btn-dark shadow p-1 mb-5 bg-body rounded mt-1 mx-2 dropdown-toggle" type="button" aria-expanded="true"> 커리어  <span class="caret"></span>
#                   </button>
#                       <ul role="menu" class="dropdown-menu">
#                         <li><a href="#"> 실무역량 </a> </li>
#                         <li><a href="#"> 마케팅 </a> </li>
#                         <li><a href="#"> 취업/이직/진로 </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 엑셀💻 </a> </li>
#                         <li><a href="#"> 파워포인트💻 </a> </li>
#                         <li><a href="#"> 스피치 </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 📊데이터분석📊 </a> </li>
#                         <li><a href="#"> 웹개발 </a> </li>
#                         <li><a href="#"> 📱앱개발📲</a> </li>
#                         <li><a href="#"> 💻컴퓨터공학💻 </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 자격증/시험 </a> </li>
#                         </ul>
#
#             </div><!--Container closed-->
#             <div class="dropdown-container"><!--Container wrapped around-->
#               <button data-toggle="dropdown" class="btn-outline-dark shadow p-1 mb-5 bg-body rounded mt-1 mx-2 dropdown-toggle" type="button" aria-expanded="true"> 디자인/영상 <span class="caret"></span>
#                   </button>
#                       <ul role="menu" class="dropdown-menu">
#                         <li><a href="#"> 건축 </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 그래픽디자인💻 </a> </li>
#                         <li><a href="#"> UI/UX디자인💻 </a> </li>
#                         <li><a href="#"> 제품디자인 </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 영상편집🎥 </a> </li>
#                         <li><a href="#"> 🎬영상제작🎬 </a> </li>
#                         </ul>
#
#             </div><!--Container closed-->
#
#             <div class="dropdown-container"><!--Container wrapped around-->
#               <button data-toggle="dropdown" class="btn-dark shadow p-1 mb-5 bg-body rounded mt-1 mx-2 dropdown-toggle" type="button" aria-expanded="true"> 외국어 <span class="caret"></span>
#                 </button>
#                       <ul role="menu" class="dropdown-menu">
#                         <li><a href="#"> 영어회화💬 </a> </li>
#                         <li><a href="#"> 🗨️중국어회화🀄 </a> </li>
#                         <li><a href="#"> 일본어회화 </a> </li>
#                         <li><a href="#">📜어학자격증🧾 </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#"> 기타외국어📚 </a> </li>
#                         </ul>
#
#             </div><!--Container closed-->
#
#             <div class="dropdown-container">
#               <button data-toggle="dropdown" class="btn btn-success dropdown-toggle btn-xs rounded shadow p-1 mb-5 mt-1 mx-2" type="button" aria-expanded="true"> 신규강좌 <span class="caret"></span>
#                 </button>
#                     <ul role="menu" class="dropdown-menu">
#                         <li><a href="#"> 👾펀딩👾 </a> </li>
#                         <li><a href="#"> 💬오픈예정💬 </a> </li>
#                         <li><a href="#"> 좋아요😍👍 </a> </li>
#                         <li class="dropdown-divider"></li>
#                         <li><a href="#">😊신규강좌🙋‍♀</a> </li>
#                         </ul>
#
#             </div><!--Container closed-->
#
#         </div>
#
#         <br>
#         <div class="show-datas row">
#
#             <table id="report" class="table table-striped searching table-hover">
#                 <thead>
#                     <tr>
#                         <th scope="col" width="80">사이트</th>
#                         <th scope="col" width="150">강의 제목</th>
#                         <th scope="col" width="100">분류1</th>
#                         <th scope="col" width="70">분류2</th>
#                         <th scope="col" width="130">강의 가격</th>
#                         <th scope="col" width="70">할인률</th>
#                         <th scope="col" width="100">만족도</th>
#                         <th scope="col" width="100">새창보기</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                 </tbody>
#             </table>
#         </div>
#         <div class="form-group">
#             <label for="comment">Comment:</label>
#             <textarea class="form-control" rows="10" id="comment"></textarea>
#         </div>
#
#         <!-- 신규강좌 -->
#         <div class='row'>
#             <div type='button' id = 'new_class' class="col-12 btn btn-dark alert-dark mt-2" role="alert">
#             ⏰  신규 강좌  ⏰    ****  ❗❕❗❕ "새로 추가된 강좌를 확인하세요!"❗❕❗❕
#             </div>
#             <table id="report" class="table table-striped new table-hover">
#                 <thead>
#                     <tr>
#                         <th scope="col" width="80">사이트</th>
#                         <th scope="col" width="150">강의 제목</th>
#                         <th scope="col" width="100">분류1</th>
#                         <th scope="col" width="70">분류2</th>
#                         <th scope="col" width="130">강의 가격</th>
#                         <th scope="col" width="70">할인률</th>
#                         <th scope="col" width="100">만족도</th>
#                         <th scope="col" width="100">새창보기</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#
#
#                 </tbody>
#             </table>
#         </div>
#
#     <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.6.0/jquery.min.js"></script>
#     <script type="text/javascript">
#         $(document).ready(function(){
#             $(".search").on("click", function(){
#                 var sentence = $('.sentence').val();
#                 var url='/search?sentence=' + sentence;
#
#                 $.getJSON(url, function(response){
#                     console.log(response.datas);
#                     var tag = "";
#                     for (var i=0; i< response.datas.length; i++){
#                         tag += '<tr onclick=location.href="' + response.datas[i].link + '" style=cursor:pointer;>';
#                         tag += '    <td>' + response.datas[i].site + '</td>';
#                         tag += '    <td>' + response.datas[i].title + '</td>';
#                         tag += '    <td>' + response.datas[i].category_1 + '</td>';
#                         tag += '    <td>' + response.datas[i].category_2 + '</td>';
#                         tag += '    <td>' + response.datas[i].s_price + '</td>';
#                         tag += '    <td>' + response.datas[i].discount + '</td>';
#                         tag += '    <td>' + response.datas[i].contentment + '</td>';
#                         tag += '    <td>' + `<a href="${response.datas[i].link}" target="_blank">${response.datas[i].title}</a>` + '</td>'
#                         tag += '</tr>';
#                     }
#                     $(".searching tbody").html(tag);
#
#                 })
#             })
#         });
#          $(document).ready(function(){
#            $("#new_class").on('click', function(){
#                 var url_new='/new_class';
#
#                 $.getJSON(url_new, function(response){
#                     console.log(response.datas_new);
#                     var tag = "";
#                     for (var i=0; i< response.datas_new.length; i++){
#                         tag += '<tr onclick=location.href="' + response.datas_new[i].link + '" style=cursor:pointer;>';
#                         tag += '    <td>' + response.datas_new[i].site + '</td>';
#                         tag += '    <td>' + response.datas_new[i].title + '</td>';
#                         tag += '    <td>' + response.datas_new[i].category_1 + '</td>';
#                         tag += '    <td>' + response.datas_new[i].category_2 + '</td>';
#                         tag += '    <td>' + response.datas_new[i].s_price + '</td>';
#                         tag += '    <td>' + response.datas_new[i].discount + '</td>';
#                         tag += '    <td>' + response.datas_new[i].contentment + '</td>';
#                         tag += '    <td>' + `<a href="${response.datas_new[i].link}" target="_blank">${response.datas_new[i].title}</a>` + '</td>'
#                         tag += '</tr>';
#                     }
#                     $(".new tbody").html(tag);
#
#                 })
#             })
#         });
#     </script>
#
#     </div>
#     </div>
# </body>
# </html>
# Out:
# Overwriting webservice/templates/index.html

# %%
#    <div>
#           <form>
#         <div class="input-group">
#           <span class="input-group-addon rounded mx-5 mt-10"><i class="glyphicon glyphicon-user"></i></span>
#           <input id="email" type="text" class="form-control" name="email" placeholder="Email">
#         </div>
#        
#        <br>
#        
#         <div class="input-group">
#           <span class="input-group-addon rounded mx-5 mt-10"><i class="glyphicon glyphicon-lock"></i></span>
#           <input id="password" type="password" class="form-control" name="password" placeholder="Password">
#         </div>
#        
#        <br>
#        
#         <div class="input-group">
#           <span class="input-group-addonrounded mx-5 mt-10"></span>
#           <input id="msg" type="text" class="form-control" name="msg" placeholder="Additional Info">
#         </div>
#       </form>

# %%
    <style>
        .hye {
          position: absolute;
            background-color: red;
            margin-left: 400px;
            object-fit: contain;
            left: 0px;    
            top: 0px; 
        }

    </style>
    
        <div class="hye">
        <img style="object-fit:contain;" src="https://i.ibb.co/x3w3SyR/flask.png" alt="flask" border="0">
    </div>

# %%
    <img id="test2" src="https://i.ibb.co/0qv9tN7/dd.png" width="140" height="200" border="0">

# %%
<th scope="col"width="10">#</th>
                       // tag += '    <td>' + i + '</td>';
